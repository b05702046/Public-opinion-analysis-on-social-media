# %%
pip install requests_html
# Out:
# ...
#
# ...

# %%
import pandas as pd 
import requests
from requests_html import HTML 
import re

ID = '235105135'
url = 'https://www.dcard.tw/_api/posts/'+ ID
# 透過request套件抓下這個網址的資料
requ = requests.get(url)
# 初步檢視抓到的資料結構

rejs = requ.json()
print(type(rejs))
pd.DataFrame(
    data=
    [{'ID':rejs['id'],
      'title':rejs['title'],
      'content':rejs['content'],
      'excerpt':rejs['excerpt'],
      'createdAt':rejs['createdAt'],
      'updatedAt':rejs['updatedAt'],
      'commentCount':rejs['commentCount'],
      'forumName':rejs['forumName'],
      'forumAlias':rejs['forumAlias'],
      'gender':rejs['gender'],
      'likeCount':rejs['likeCount'],
      'reactions':rejs['reactions'],
      'topics':rejs['topics']}],
    columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics'])
# Out:
# <class 'dict'>
#           ID                                 title  \
# 0  235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
#
#                                              content  \
# 0  https://i.imgur.com/abibv7x.jpg\nhttps://i.img...
#
#                                              excerpt  \
# 0  2021/1/3，剛才看到新聞，好奇去看一下他們Google評價，結果沒跟媒體上說的一樣被洗...
#
#                   createdAt                 updatedAt  commentCount forumName  \
# 0  2021-01-03T15:08:05.771Z  2021-01-04T14:15:29.165Z           196        時事
#
#   forumAlias gender  likeCount  \
# 0   trending      M        842
#
#                                            reactions  \
# 0  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
#
#                        topics
# 0  [台灣, 台中, 北屯, 富王鴨肉專門店, 軍功路]

# %%
import pandas as pd 
import requests
from requests_html import HTML 
import re

#ID = '235105135'

url_2 =  ' https://www.dcard.tw/service/api/v2/forums/trending/posts'
# 透過request套件抓下這個網址的資料
requ_2 = requests.get(url_2)
rejs_2 = requ_2.json()
display = []
rejs_2
for i in rejs_2:
    display.append(i['id'])
    print(i['id'])

    
        
display[0]
# Out:
# 235109827
# 235109812
# 235109604
# 235109575
# 235109451
# 235109412
# 235109355
# 235109033
# 235108988
# 235108942
# 235108921
# 235108854
# 235108681
# 235108627
# 235108525
# 235108490
# 235108463
# 235108407
# 235108375
# 235108319
# 235108063
# 235107998
# 235107928
# 235107849
# 235107768
# 235107741
# 235107692
# 235107668
# 235107563
# 235107177
# 235109827

# %%
df = pd.DataFrame()
for i in display:
    df = df.append(Crawl(i),ignore_index = True)
df
# Out:
#            ID                                              title  \
# 0   235109827                                  16歲就當爸 19歲迎第二胎後自殺
# 1   235109812                        「天網」引發侵害隱私疑慮 國家人權委員籲指揮中心說清楚
# 2   235109604                           那個已經沒用了 別再説柯文哲（哪裡好）已經沒用了
# 3   235109575                              笑死 神偷貓咪爆紅 主人取名叫做China
# 4   235109451                            高雄醫美貴婦控3千萬財物被搬空 警拘提1男到案
# 5   235109412                 溫泉飯店1晚8千！「刷卡秒變9萬」她嚇傻　怒戰訂房網10天揭驚人內幕
# 6   235109355                                              日本辱華吧
# 7   235109033                                    給那些只會搬美牛出來擋的817
# 8   235108988  PTT站務總監+1 ？  批踢踢站長群集體失蹤駭人事件  站長現實中的真實身份知之者少之又少...
# 9   235108942                          更遠更準! IDF試射"萬劍彈" 可癱瘓陸沿岸軍設
# 10  235108921                                    零檢出違憲？蘇貞昌：依憲法執行
# 11  235108854                                          防疫你我他她牠它祂
# 12  235108681                              路平燈亮水溝通，20年首見無登革熱本土病例
# ...

# %%
import csv
df.to_csv(r'C:\Users\王立宇\Desktop\dcard_sample.csv',encoding="utf_8_sig")

# %%
last = '235109827'
id_list = []
id_list.append(last)
id_list[-1]
# Out:
# '235109827'

# %%
last = '235109827'
id_list.append(last)
for i in range(500):
    last = str(id_list[-1])
    link = 'https://www.dcard.tw/service/api/v2/forums/trending/posts?popular=false&limit=100&before='+last
    requ_3 = requests.get(link)
    rejs_3 = requ_3.json()
    for j in rejs_3:
        id_list.append(j['id'])
print(id_list)
# Out:
# ['235109827', '235109827', 235109812, 235109604, 235109575, 235109451, 235109412, 235109355, 235109033, 235108988, 235108942, 235108921, 235108854, 235108681, 235108627, 235108525, 235108490, 235108463, 235108407, 235108375, 235108319, 235108063, 235107998, 235107928, 235107849, 235107768, 235107741, 235107692, 235107668, 235107563, 235107177, 235107025, 235106976, 235106937, 235106915, 235106858, 235106852, 235106655, 235106233, 235105557, 235105379, 235105223, 235105135, 235105034, 235105016, 235104905, 235104903, 235104813, 235104689, 235104589, 235104454, 235104433, 235104426, 235104411, 235104313, 235104312, 235104208, 235104203, 235104140, 235104071, 235104067, 235103903, 235103693, 235103577, 235103534, 235103483, 235103292, 235103277, 235103175, 235103149, 235103129, 235103026, 235102887, 235102727, 235102709, 235102462, 235102392, 235102370, 235102273, 235102266, 235102195, 235102175, 235102155, 235101868, 235101801, 235101772, 235101757, 235101685, 235101674, 235101589, 235
# ...

# %%
last = '235109827'
id_list_hundred = []
id_list_hundred.append(last)
for i in range(100):
    last = str(id_list_hundred[-1])
    link = 'https://www.dcard.tw/service/api/v2/forums/trending/posts?popular=false&limit=100&before='+last
    requ_4 = requests.get(link)
    rejs_4 = requ_4.json()
    for j in rejs_4:
        id_list_hundred.append(j['id'])
print(id_list_hundred)
# Out:
# ['235109827', 235109812, 235109604, 235109575, 235109451, 235109412, 235109355, 235109033, 235108988, 235108942, 235108921, 235108854, 235108681, 235108627, 235108525, 235108490, 235108463, 235108407, 235108375, 235108319, 235108063, 235107998, 235107928, 235107849, 235107768, 235107741, 235107692, 235107668, 235107563, 235107177, 235107025, 235106976, 235106937, 235106915, 235106858, 235106852, 235106655, 235106233, 235105557, 235105379, 235105223, 235105135, 235105034, 235105016, 235104905, 235104903, 235104813, 235104689, 235104589, 235104454, 235104433, 235104426, 235104411, 235104313, 235104312, 235104208, 235104203, 235104140, 235104071, 235104067, 235103903, 235103693, 235103577, 235103534, 235103483, 235103292, 235103277, 235103175, 235103149, 235103129, 235103026, 235102887, 235102727, 235102709, 235102462, 235102392, 235102370, 235102273, 235102266, 235102195, 235102175, 235102155, 235101868, 235101801, 235101772, 235101757, 235101685, 235101674, 235101589, 235101406, 23510
# ...

# %%
df5 = CrawlerV2(235109827)
last = '235109827'
id_list_ten = []
id_list_ten.append(last)
for i in range(50):
    last = str(int(df5.tail(1).ID))
    link = 'https://www.dcard.tw/service/api/v2/forums/trending/posts?popular=false&limit=100&before='+last
    requ_4 = requests.get(link)
    rejs_4 = requ_4.json()
    for j in range(len(rejs_4)):
        df5 = df5.append(CrawlerV2(rejs_4[j]['id']), ignore_index=True)
        df5
        time.sleep(0.2)
        
df5
# Out:
#              ID                               title  \
# 0     235109827                   16歲就當爸 19歲迎第二胎後自殺
# 1     235109604            那個已經沒用了 別再説柯文哲（哪裡好）已經沒用了
# 2     235109575               笑死 神偷貓咪爆紅 主人取名叫做China
# 3     235109451             高雄醫美貴婦控3千萬財物被搬空 警拘提1男到案
# 4     235109412  溫泉飯店1晚8千！「刷卡秒變9萬」她嚇傻　怒戰訂房網10天揭驚人內幕
# ...         ...                                 ...
# 4996  234614277           刑法擬修正 滿12歲擔責 姦淫不滿10歲幼女可判死
# 4997  234614234               傳管浩鳴赴台駐港機構 為陳同佳辦入台證遭拒
# 4998  234614168                               Xpark
# 4999  234614157            G邁統治高雄46天 【進步之大 眾人都驚呆了 】
# 5000  234614094                    因為這件事 不知道又有多少人失業
#
#                                                 content  \
# 0     美國一對小爸媽16歲便懷孕生子，並將育兒過程上傳至YouTube，引起外界關注，吸引超過15...
# 1     柯學就是唬爛\n被抓包時才是説謊\n\n好事柯文哲\n壞處推別人\n\n#沒有承擔\n\n\...
# 2     真是貓如其名阿XD完蛋了又辱華\n中國就是最愛偷阿，智慧財產機密資訊哪個不偷\n\n\nht...
# 3     高雄1間從事醫美的貴婦今天在臉書發文，指控她收的「乾兒子」，竟趁機潛入她家，搬空2克拉鑽戒、...
# ...

# %%
df5.to_csv(r'C:\Users\王立宇\Desktop\dcard_sample115.csv',encoding="utf_8_sig")

# %%
for j in range(10):
    last = int(df.tail(1).ID) # 找出爬出資料的最後一筆ID
    url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100&before=' + str(last)
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Crawl(rejs[i]['id']), ignore_index=True)
print(df.shape)
df
# Out:
# (30, 13)
#            ID                                              title  \
# 0   235109827                                  16歲就當爸 19歲迎第二胎後自殺
# 1   235109812                        「天網」引發侵害隱私疑慮 國家人權委員籲指揮中心說清楚
# 2   235109604                           那個已經沒用了 別再説柯文哲（哪裡好）已經沒用了
# 3   235109575                              笑死 神偷貓咪爆紅 主人取名叫做China
# 4   235109451                            高雄醫美貴婦控3千萬財物被搬空 警拘提1男到案
# 5   235109412                 溫泉飯店1晚8千！「刷卡秒變9萬」她嚇傻　怒戰訂房網10天揭驚人內幕
# 6   235109355                                              日本辱華吧
# 7   235109033                                    給那些只會搬美牛出來擋的817
# 8   235108988  PTT站務總監+1 ？  批踢踢站長群集體失蹤駭人事件  站長現實中的真實身份知之者少之又少...
# 9   235108942                          更遠更準! IDF試射"萬劍彈" 可癱瘓陸沿岸軍設
# 10  235108921                                    零檢出違憲？蘇貞昌：依憲法執行
# 11  235108854                                          防疫你我他她牠它祂
# 12  235108681                              路平燈亮水溝通，20年首見無登革熱本土病例
# ...

# %%
id_list_ten
# Out:
# ['235109827',
#  234201563,
#  234201485,
#  234201417,
#  234201234,
#  234201177,
#  234201167,
#  234201140,
#  234201115,
#  234201064,
#  234201063,
#  234201038,
#  234200953,
#  234200939,
#  234200858,
#  234200698,
#  234200683,
#  234200670,
#  234200588,
#  234200575,
#  234200488,
#  234200465,
#  234200339,
#  234200292,
#  234200261,
#  234200160,
#  234200144,
#  234200105,
#  234200083,
#  234199935,
#  234199924,
#  234199920,
#  234199863,
#  234199838,
#  234199809,
#  234199629,
#  234199617,
#  234199584,
#  234199551,
#  234199516,
#  234199486,
#  234199469,
#  234199439,
#  234199436,
#  234199433,
#  234199419,
#  234199391,
#  234199378,
#  234199339,
#  234199095,
#  234198753,
#  234198320,
#  234198091,
#  234197939,
#  234197190,
#  234197102,
#  234196995,
#  234196830,
#  234196827,
#  234196653,
#  234196642,
#  234196629,
#  234196548,
#  234196450,
#  234196296,
#  234196173,
#  234196085,
#  234195859,
#  234195854,
#  234195762,
#  234195719,
# ...

# %%
df4 = pd.DataFrame()
test = 0
for i in id_list_ten:
    test = test + 1
    df4 = df4.append(CrawlerV2(i),ignore_index = True)
    time.sleep(0.2)
    
df4
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-169-ce914d65769d> in <module>
#       3 for i in id_list_ten:
#       4     test = test + 1
# ----> 5     df4 = df4.append(CrawlerV2(i),ignore_index = True)
#       6     time.sleep(0.2)
#       7
#
# <ipython-input-167-10045cce88e9> in CrawlerV2(id)
#       1 def CrawlerV2(id):
#       2     linktopage = 'https://www.dcard.tw/service/api/v2/posts/' + str(id)
# ----> 3     request = requests.get(linktopage)
#       4     ans = request.json()
#       5     ans
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
# ...

# %%
last = '235109827'
linktopage = 'https://www.dcard.tw/service/api/v2/posts/' + last
request = requests.get(linktopage)
ans = request.json()
ans

pd.DataFrame(
    data=
    [{'ID':rejs['id'],
      'title':rejs['title'],
      'content':rejs['content'],
      'excerpt':rejs['excerpt'],
      'createdAt':rejs['createdAt'],
      'updatedAt':rejs['updatedAt'],
      'commentCount':rejs['commentCount'],
      'forumName':rejs['forumName'],
      'forumAlias':rejs['forumAlias'],
      'gender':rejs['gender'],
      'likeCount':rejs['likeCount'],
      'reactions':rejs['reactions'],
      'topics':rejs['topics']}],
    columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics'])
# Out:
#           ID                                 title  \
# 0  235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
#
#                                              content  \
# 0  https://i.imgur.com/abibv7x.jpg\nhttps://i.img...
#
#                                              excerpt  \
# 0  2021/1/3，剛才看到新聞，好奇去看一下他們Google評價，結果沒跟媒體上說的一樣被洗...
#
#                   createdAt                 updatedAt  commentCount forumName  \
# 0  2021-01-03T15:08:05.771Z  2021-01-04T14:15:29.165Z           196        時事
#
#   forumAlias gender  likeCount  \
# 0   trending      M        842
#
#                                            reactions  \
# 0  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
#
#                        topics
# 0  [台灣, 台中, 北屯, 富王鴨肉專門店, 軍功路]

# %%
def CrawlerV2(id):
    linktopage = 'https://www.dcard.tw/service/api/v2/posts/' + str(id)
    request = requests.get(linktopage)
    ans = request.json()
    ans

    return (pd.DataFrame(
            data=
            [{'ID':ans['id'],
              'title':ans['title'],
              'content':ans['content'],
              'excerpt':ans['excerpt'],
              'createdAt':ans['createdAt'],
              'updatedAt':ans['updatedAt'],
              'commentCount':ans['commentCount'],
              'forumName':ans['forumName'],
              'forumAlias':ans['forumAlias'],
              'gender':ans['gender'],
              'likeCount':ans['likeCount'],
              'reactions':ans['reactions'],
              'topics':ans['topics']}],
            columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics']))

# %%
aaa = CrawlerV2(234201417)
bbb = CrawlerV2(235109827)
aaa = aaa.append(bbb)
aaa
# Out:
#           ID              title  \
# 0  234201417      president she
# 0  235109827  16歲就當爸 19歲迎第二胎後自殺
#
#                                              content  \
# 0  蔡英文點頭了耶\n\n英文點頭\n\npresident she\n她是總統\n\n733右...
# 0  美國一對小爸媽16歲便懷孕生子，並將育兒過程上傳至YouTube，引起外界關注，吸引超過15...
#
#                                              excerpt  \
# 0  蔡英文點頭了耶，英文點頭，president she，她是總統，733右腦學習記憶法，蔡英文...
# 0  美國一對小爸媽16歲便懷孕生子，並將育兒過程上傳至YouTube，引起外界關注，吸引超過15...
#
#                   createdAt                 updatedAt  commentCount forumName  \
# 0  2020-08-10T08:27:20.469Z  2020-08-10T11:18:43.501Z            29        時事
# 0  2021-01-04T09:12:07.970Z  2021-01-04T09:12:07.970Z           145        時事
#
#   forumAlias gender  likeCount  \
# 0   trending      M         61
# 0   trending      M       5045
#
#                                            reactions            topics
# 0  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...         [台灣, 蔡英文]
# ...

# %%
int(aaa.tail(1).ID)
# Out:
# 235109827

# %%
len(id_list_ten)
# Out:
# 3001

# %%
df4 = pd.DataFrame()
test = 0
for i in id_list_ten:
    test = test + 1
    df4 = df4.append(CrawlerV2(i),ignore_index = True)
    time.sleep(0.2)
    
df4
# Out:
#              ID                              title  \
# 0     235109827                  16歲就當爸 19歲迎第二胎後自殺
# 1     234201563                       各位菸糞好，要XI菸嗎？
# 2     234201485             強烈呼籲國安法嚴懲以下勾結境外勢力的反動分子
# 3     234201417                      president she
# 4     234201234      我嚴重懷疑美衛生部長阿札爾不知道台灣和中國是不是同一個地方
# ...         ...                                ...
# 2996  234194446                     南北不同命 肺癌風險差15倍
# 2997  234194443    吳益政陳其邁哪個好？柯文哲媽媽：陳其邁是好人 當選對高雄也不錯
# 2998  234194370                柯文哲：政治正常就好 良心不要被狗吃了
# 2999  234194368    有個富爸爸真麻煩呀！Tiktok和微軟與富爸爸們一起過的88節
# 3000  234194354  八大場所未戴口罩雲林將開罰 家長：說好送給全縣學生的第二盒口罩呢？
#
#                                                 content  \
# 0     美國一對小爸媽16歲便懷孕生子，並將育兒過程上傳至YouTube，引起外界關注，吸引超過15...
# 1     嘻嘻嘻嘻嘻嘻  \n習英文🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣\n不要再無腦護航了\n一直硬凹\n你的英文...
# 2     1929年中東路事件爆發後，共產國際遠東局明確要求中共中央要提出「武裝保衛蘇聯」的口號，並組...
# 3     蔡英文點頭了耶\n\n英文點頭\n\npresident she\n她是總統\n\n733右...
# 4     美國衛生部長阿札爾來台灣訪問，是1979年以來訪台層級最高，也是6年來首位訪台的美國部長級官...
# ...

# %%
df4.to_csv(r'C:\Users\王立宇\Desktop\dcard_sample_55.csv',encoding="utf_8_sig")

# %%
df3 = pd.DataFrame()
test = 0
for i in id_list_ten:
    test = test + 1
    df3 = df3.append(CrawlerV2(i),ignore_index = True)
    time.sleep(0.2)
    
print(test)
df3
# Out:
# 3001
#              ID                                 title  \
# 0     235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# 1     235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# 2     235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# 3     235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# 4     235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# ...         ...                                   ...
# 2996  235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# 2997  235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# 2998  235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# 2999  235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
# 3000  235105135  不爽拖餐被詢問鴨肉店恐嚇外送員『沒被打過是不是？我就在威脅你有種來告我』
#
#                                                 content  \
# 0     https://i.imgur.com/abibv7x.jpg\nhttps://i.img...
# 1     https://i.imgur.com/abibv7x.jpg\nhttps://i.img...
# 2     https://i.imgur.com/abibv7x.jpg\nhttps://i.img...
# 3     https://i.imgur.com/abibv7x.jpg\nhttps://i.img...
# ...

# %%
df3.to_csv(r'C:\Users\王立宇\Desktop\dcard_sample_3.csv',encoding="utf_8_sig")

# %%
aaa = CrawlerV2(last)
aaa.to_csv(r'C:\Users\王立宇\Desktop\dcard_sample_10.csv',encoding="utf_8_sig")

# %%
import pandas as pd
import datetime
import requests
import sched
import time
import json


df2 = pd.DataFrame()
test = 0
for i in id_list_ten:
    test = test + 1
    df2 = df2.append(Crawl(i),ignore_index = True)
    time.sleep(1.5)
    
print(test)
df2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-146-976ed43052d7> in <module>
#      12     test = test + 1
#      13     df2 = df2.append(Crawl(i),ignore_index = True)
# ---> 14     time.sleep(1.5)
#      15
#      16 print(test)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import datetime
import requests
import sched
import time
import json


df2 = pd.DataFrame()
test = 0
for i in id_list_hundred:
    test = test + 1
    df2 = df2.append(Crawl(i),ignore_index = True)
    time.sleep(1.5)
    
print(test)
df2
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# D:\anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
df2.to_csv(r'C:\Users\王立宇\Desktop\dcard_sample_2.csv',encoding="utf_8_sig")

# %%
pip install dcard

# %%
from dcard import Dcard

# %%
print(len(id_list))
# Out:
# 70206

# %%
def Crawl(ID):
    link = 'https://www.dcard.tw/_api/posts/' + str(ID)
    requ = requests.get(link)
    rejs = requ.json()
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt':rejs['updatedAt'],
          'commentCount':rejs['commentCount'],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'likeCount':rejs['likeCount'],
          'reactions':rejs['reactions'],
          'topics':rejs['topics']}],
        columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics']))

# %%
df = pd.DataFrame()
for i in id_list:
    df = df.append(Crawl(i),ignore_index = True)
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-199cb04e6baf> in <module>
#       1 df = pd.DataFrame()
#       2 for i in id_list:
# ----> 3     df = df.append(Crawl(i),ignore_index = True)
#       4 print(df.shape)
#
# <ipython-input-52-cdf0a9512f03> in Crawl(ID)
#       1 def Crawl(ID):
#       2     link = 'https://www.dcard.tw/_api/posts/' + str(ID)
# ----> 3     requ = requests.get(link)
#       4     rejs = requ.json()
#       5     return(pd.DataFrame(
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
# ...

# %%
url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(Crawl(rejs[i]['id']),ignore_index=True)
print(df.shape)
df
# Out:
# (100, 13)
#            ID                 title  \
# 0   235103345        我跟店員說不要(ಥ_ಥ)……
# 1   235101814   0102我的老家發生火災了......
# 2   235101651        請夏呀，跑累了就停下喘口氣吧
# 3   235101933            拍個照有必要貼上去嗎
# 4   235101640  #分享 無法飛上天的小小空服員愛用底妝✈
# ..        ...                   ...
# 95  235102204                  劈腿穿搭
# 96  235103946          是我太不會聊天嗎🤦‍♂️
# 97  235104698          冬天我想這樣穿 穿搭分享
# 98  235102510             單身的我看這種影片
# 99  235101456            一見鍾情真的存在嗎?
#
#                                               content  \
# 0   平常講話習慣用疊字\n\n像是 吃飯飯之類的(๑•́ ₃ •̀๑)\n\n\n\n\n剛剛去...
# 1   昨天中午的12點58分\n原本在睡午覺的我接到了媽媽打來的電話\n說爺爺開電暖器忘記關就出門...
# 2   「사람이 어떻게 계속 달려」    - 하니   —달리는 사이\n人怎麼能夠一直不停地奔...
# 3   中文是看不懂嗎？\n一開始他們跨進去已經很無言\n後面直接貼上去拍\n完全無視請勿跨越的標示...
# 4   自從疫情關係回台灣待命後在家廢了好久\n趁這時候分享自己平常上班愛用底妝～～\n \n大家都...
# ..                                                ...
# 95  https://i.imgur.com/MqQ6hDJ.jpg\n\n最近在學如何劈腿腿 就...
# 96  最近想嘗試玩交友軟體！好不容易才配對到一個，沒想到才聊不到幾句話對方就離開聊天室！有種小小的...
# ...

# %%
for j in range(10):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Crawl(rejs[i]['id']), ignore_index=True)
print(df.shape)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-ff57eb6f681c> in <module>
#       5     rejs = resq.json()
#       6     for i in range(len(rejs)):
# ----> 7         df = df.append(Crawl(rejs[i]['id']), ignore_index=True)
#       8 print(df.shape)
#       9 df
#
# <ipython-input-52-cdf0a9512f03> in Crawl(ID)
#       5     return(pd.DataFrame(
#       6         data=
# ----> 7         [{'ID':rejs['id'],
#       8           'title':rejs['title'],
#       9           'content':rejs['content'],
#
# KeyError: 'id'

# %%
import pandas as pd 
import requests
from requests_html import HTML
import time
import re
import csv
from tqdm import tqdm, trange
import random


def CrawlerV2(id):
    linktopage = 'https://www.dcard.tw/service/api/v2/posts/' + str(id)
    request = requests.get(linktopage)
    ans = request.json()
    ans

    return (pd.DataFrame(
            data=
            [{'ID':ans['id'],
              'title':ans['title'],
              'content':ans['content'],
              'excerpt':ans['excerpt'],
              'createdAt':ans['createdAt'],
              'updatedAt':ans['updatedAt'],
              'commentCount':ans['commentCount'],
              'forumName':ans['forumName'],
              'forumAlias':ans['forumAlias'],
              'gender':ans['gender'],
              'likeCount':ans['likeCount'],
              'reactions':ans['reactions'],
              'topics':ans['topics']}],
            columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics']))



 
delay_choices = [0.2, 0.05, 0.1, 0.06, 0.15, 0.5]  #延遲的秒數


times = 0
progress = tqdm(total=901)

df5 = CrawlerV2(234253899)
last = '234253899'
id_list_ten = []
id_list_ten.append(last)
for i in range(100):
    last = str(int(df5.tail(1).ID))
    link = 'https://www.dcard.tw/service/api/v2/forums/trending/posts?popular=false&limit=100&before='+last
    requ_4 = requests.get(link)
    rejs_4 = requ_4.json()
    for j in range(len(rejs_4)):
        df5 = df5.append(CrawlerV2(rejs_4[j]['id']), ignore_index=True)
        progress.update(1)
        times += 1
        delay = random.choice(delay_choices)
        time.sleep(delay)
# Out:
#  19%|█████████████▉                                                            | 943/5001 [5:15:51<22:39:14, 20.10s/it]
#
# ...
#   4%|███                                                                           | 398/10001 [02:21<57:32,  2.78it/s]
# ...
# ...
# 100%|███████████████████████████████████████████████████████████████████████████▉| 10000/10001 [59:22<00:00,  2.68it/s]

# %%
delay_choices = [0.2, 0.05, 0.1, 0.06, 0.15, 0.5]  #延遲的秒數


times = 0
progress = tqdm(total=43)



df5 = CrawlerV2(234512273)
last = '234512273'
id_list_ten = []
id_list_ten.append(last)

last = str(int(df5.tail(1).ID))
link = 'https://www.dcard.tw/service/api/v2/forums/trending/posts?popular=false&limit=100&before='+last
requ_4 = requests.get(link)
rejs_4 = requ_4.json()
for j in range(len(rejs_4)):
    if j == 44:
        break
    df5 = df5.append(CrawlerV2(rejs_4[j]['id']), ignore_index=True)
    progress.update(1)
    times += 1
    delay = random.choice(delay_choices)
    time.sleep(delay)
# Out:
# 44it [02:11,  2.99s/it]                                                                         | 0/43 [00:00<?, ?it/s]
# 44it [00:20,  2.88it/s]

# %%
df5.to_csv(r'C:\Users\王立宇\Desktop\dcard_sample_43.csv',encoding="utf_8_sig")

# %%
df10 = pd.read_csv(r'C:\Users\王立宇\Desktop\dcard\dcard_5000.csv')
df11 = pd.read_csv(r'C:\Users\王立宇\Desktop\dcard\dcard_sample_900.csv')
df12 = pd.read_csv(r'C:\Users\王立宇\Desktop\dcard\dcard_sample_43.csv')
df13 = pd.read_csv(r'C:\Users\王立宇\Desktop\dcard\Dcard_start234508903_last234253899.csv')
df14 = pd.read_csv(r'C:\Users\王立宇\Desktop\dcard\dcard_sample_10000.csv')

# %%
df_final = pd.DataFrame()
df_final = df_final.append(df10)
df_final = df_final.append(df11)
df_final = df_final.append(df12)
df_final = df_final.append(df13)
df_final = df_final.append(df14)
df_final
# Out:
#        Unnamed: 0         ID                               title  \
# 0               0  235109827                   16歲就當爸 19歲迎第二胎後自殺
# 1               1  235109604            那個已經沒用了 別再説柯文哲（哪裡好）已經沒用了
# 2               2  235109575               笑死 神偷貓咪爆紅 主人取名叫做China
# 3               3  235109451             高雄醫美貴婦控3千萬財物被搬空 警拘提1男到案
# 4               4  235109412  溫泉飯店1晚8千！「刷卡秒變9萬」她嚇傻　怒戰訂房網10天揭驚人內幕
# ...           ...        ...                                 ...
# 9996         9996  233470033                 佳龍的華航改名計時器！滿滿的台灣價值！
# 9997         9997  233469952         關於警察踢少年頭事件 .網友居然回「也想踢」？？？？？
# 9998         9998  233469792              綠衛兵又出征！林書豪臉書稱新冠病毒遭覺青灌爆
# 9999         9999  233469614                          到底在自嗨什麼...
# 10000       10000  233469264                    口罩販賣機出現bug可重複購買！
#
#                                                  content  \
# 0      美國一對小爸媽16歲便懷孕生子，並將育兒過程上傳至YouTube，引起外界關注，吸引超過15...
# 1      柯學就是唬爛\n被抓包時才是説謊\n\n好事柯文哲\n壞處推別人\n\n#沒有承擔\n\n\...
# ...

# %%
df_final.to_csv(r'C:\Users\王立宇\Desktop\dcard\dcard_final.csv',encoding="utf_8_sig")
